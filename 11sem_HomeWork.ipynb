# %% [markdown]
# ## Импорты

# %%
# Библиотека для работы с табличными данными
import pandas as pd

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Чтение и предварительный просмотр данных

# %% [markdown]
# Библиотека **pandas** может читать многие форматы, включая: **.csv, .xslx, .xls, .txt, sql** и многие другие.
#
# Полный список по [ссылке](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html)

# %%
# Прочтем файл .csv с помощью библиотеки pandas
df = pd.read_csv('sample_data/california_housing_train.csv')

# %% [markdown]
# ```
# DataFrame.head(n=5)
# Параметры:
# n: int, значение по умолчанию 5
# ```

# %%
# Посмотреть первые 5 строк 
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# ```
# DataFrame.tail(n=5)
# Параметры:
# n: int, значение по умолчнию 5
# ```

# %%
# Посмотреть последние 5 строк
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
# Возвращает размеры таблицы: кортеж из 2 значений, 1 кол-во строк, 2 - кол-во столбцов
df.shape
# Out:
# (17000, 9)

# %%
# Посмотреть есть ли у нас пустые значения
# В данном случае пустых значений нет
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
# Проверить тип данных в столбцах
# В данных случаях везде float, число 64 указывает на разрядность(Используется 64 байта для хранения значения в памяти,
# чем меньше разрядность, тем меньший диапазон могут принимать числа и тем меньше тратится памяти на хранение.
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
# Посмотреть все столбцы
# Возвращает список со строками строк - названиями столбцов в таблице
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %% [markdown]
# В данном случае у нас следующие строки:
#
#
# 1.   **longitude** - долгота
# 2.   **latitude** - широта
# 3.   **housing_median_age** - медианный возраст зданий
# 4.   **total_rooms** - общее кол-во зданий
# 5.   **total_bedrooms** - Общее кол-во спален
# 5.   **population** - кол-во жителей
# 5.   **households** - кол-во семей
# 5.   **median_house_value** - медианная стоимость дома

# %% [markdown]
# **Медиана набора чисел** — число, которое находится в середине этого набора, если его упорядочить по возрастанию, то есть такое число, что половина из элементов набора не меньше него, а другая половина не больше.

# %% [markdown]
# # Самостоятельная практика №1
#
#
# *   Прочесть с помощью pandas файл **california_housing_test.csv**, который находится в папке **sample_data**
# *   Посмотреть сколько в нем строк и столбцов
# *   (Доп) Определить какой тип данных имеют столбцы
# *   (Доп) Проверить есть ли в файле пустые значения

# %%
calif_data = pd.read_csv('sample_data/california_housing_train.csv')

# %%
calif_data.shape
# Out:
# (17000, 9)

# %%
calif_data.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
calif_data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %% [markdown]
# # Выбор данных

# %%
# Выбор 1 столбца - [широты]
df['latitude']
# Out:
# 0        34.19
# 1        34.40
# 2        33.69
# 3        33.64
# 4        33.57
#          ...
# 16995    40.58
# 16996    40.69
# 16997    41.84
# 16998    41.80
# 16999    40.54
# Name: latitude, Length: 17000, dtype: float64

# %%
# Выбор нескольких столбцов [широта, кол-во жителей]
df[['latitude', 'population']]
# Out:
#        latitude  population
# 0         34.19      1015.0
# 1         34.40      1129.0
# 2         33.69       333.0
# 3         33.64       515.0
# 4         33.57       624.0
# ...         ...         ...
# 16995     40.58       907.0
# 16996     40.69      1194.0
# 16997     41.84      1244.0
# 16998     41.80      1298.0
# 16999     40.54       806.0
#
# [17000 rows x 2 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Выбор определенного кол-ва рядов
# Синтаксис df[df[col] !=|==|>|<| значение]
df[df['housing_median_age'] < 10]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 58       -115.52     32.67                 6.0       2804.0           581.0
# 75       -115.55     32.78                 5.0       2652.0           606.0
# 95       -115.58     32.81                 5.0        805.0           143.0
# 98       -115.58     32.78                 5.0       2494.0           414.0
# 100      -115.59     32.79                 8.0       2183.0           307.0
# ...          ...       ...                 ...          ...             ...
# 16679    -122.79     38.48                 7.0       6837.0          1417.0
# 16680    -122.79     38.42                 9.0       4967.0           885.0
# 16692    -122.82     38.55                 8.0       6190.0          1088.0
# 16776    -123.00     38.33                 8.0       3223.0           637.0
# 16854    -123.49     38.70                 9.0       5409.0          1019.0
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Для отбора можно использовать несколько условий одновременно
# Знак & означает 'and', а знак | 'or'
df[(df['housing_median_age'] > 20) & (df['total_rooms'] > 20000)]
# Out:
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value]
# Index: []

# %%
df[(df['housing_median_age']) > 20 | (df['total_rooms'] > 200)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# Выбор определенного кол-ва рядов и столбцов
# используется метод loc в [], первый аргумент индекс или селектор, а второй список со столбцами
df.loc[df['population'] < 100, ['total_bedrooms', 'total_rooms']]
# Out:
#        total_bedrooms  total_rooms
# 17               33.0         44.0
# 19               24.0         97.0
# 113              18.0         96.0
# 116              49.0        208.0
# 120              43.0        186.0
# ...               ...          ...
# 16643            73.0        255.0
# 16733           114.0        411.0
# 16743            18.0         89.0
# 16801            28.0         98.0
# 16851            35.0        133.0
#
# [178 rows x 2 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Самостоятельная практика №2
#
#
# *   Показать **median_house_value** где **median_income < 2**
# *   (Доп) Показать данные в первых 2 столбцах
# *   (Доп) Выбрать данные где **housing_median_age** < 20 и **median_house_value** > 70000

# %%
calif_data.loc[calif_data['median_income'] < 2, ['median_house_value']]
# Out:
#        median_house_value
# 0                 66900.0
# 1                 80100.0
# 2                 85700.0
# 4                 65500.0
# 7                 48500.0
# ...                   ...
# 16984             70000.0
# 16989             58100.0
# 16990             78300.0
# 16994             76100.0
# 16998             85800.0
#
# [2005 rows x 1 columns]

# %%
calif_data[['longitude', 'latitude']]
# Out:
#        longitude  latitude
# 0        -114.31     34.19
# 1        -114.47     34.40
# 2        -114.56     33.69
# 3        -114.57     33.64
# 4        -114.57     33.57
# ...          ...       ...
# 16995    -124.26     40.58
# 16996    -124.27     40.69
# 16997    -124.30     41.84
# 16998    -124.30     41.80
# 16999    -124.35     40.54
#
# [17000 rows x 2 columns]

# %%
calif_data[(calif_data['housing_median_age'] < 20) & (calif_data['median_house_value'] > 70000)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# 23       -114.98     33.82                15.0        644.0           129.0
# ...          ...       ...                 ...          ...             ...
# 16976    -124.17     40.75                13.0       2171.0           339.0
# 16983    -124.19     41.78                15.0       3140.0           714.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
#
# ...

# %% [markdown]
# # Простая статистика

# %% [markdown]
# **Pandas** позволяет получить основные простые данные для описательной статистики
#
# Такие как минимальное значение в столбце, максимальное значение, сумма всех значений, среднее значение

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Максимальное значение
print(df['population'].max())
# Минимальное значение
print(df['population'].min())
# Среднее значение
print(df['population'].mean())
# Сумма
print(df['population'].sum())
# Медианное значение
df['population'].median()
# Out:
# 35682.0
# 3.0
# 1429.5739411764705
# 24302757.0
# 1167.0

# %% [markdown]
# Эту же статистику можно рассчитывать сразу для нескольких столбцов

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Медианное значение
df[['population', 'total_rooms']].median()
# Out:
# population     1167.0
# total_rooms    2127.0
# dtype: float64

# %% [markdown]
# Получить общую картину можно простой командой **describe**

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# **count** - Общее кол-во не пустых строк
#
# **mean** - среднее значение в столбце
#
# **std** -  стандартное отклонение от среднего значения
#
# **min** - минимальное значение
#
# **max** - максимальное значение
#
# Числа **25%, 50%, 75%** - перцентили
#
# > **Перцентиль** - это показатель, используемый в статистике, показывающий значение, ниже которого падает определенный процент наблюдений в группе наблюдений

# %% [markdown]
# # Самостоятельная практика №3
#
#
#
#
# *   Определить какое максимальное и минимальное значение **median_house_value**
# * (Доп) Показать максимальное **median_house_value**, где **median_income** = 3.1250
# *  (Доп) Узнать какая максимальная **population** в зоне минимального значения **median_house_value**

# %%
print(calif_data['median_house_value'].max())
print(calif_data['median_house_value'].min())
print(calif_data.loc[calif_data['median_income'] == 3.1250, ['median_house_value']].max())
min_median_house_value = calif_data['median_house_value'].min()
min_median_house_value
calif_data.loc[(calif_data['median_house_value'] == min_median_house_value), ['population']].max()
# Out:
# 500001.0
# 14999.0
# median_house_value    380400.0
# dtype: float64
# population    628.0
# dtype: float64

# %% [markdown]
# Анализ задание про Брилианты
#
# [Текст ссылки](http://kodesource.top/python-exercises/pandas/practice-set1/index.php#EDITOR)
#
#
# ![diamond-dataset.png](data:image/png;base64,...)

# %%
di = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv', sep = ',')

# %%
di
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
di.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
print('Печать первый 7 рядов')
di.head(7)
# Out:
# Печать первый 7 рядов
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47

# %%
user_cols = ['carat', 'cut', 'x', 'y', 'z']
di[user_cols].head(3)
# Out:
#    carat      cut     x     y     z
# 0   0.23    Ideal  3.95  3.98  2.43
# 1   0.21  Premium  3.89  3.84  2.31
# 2   0.23     Good  4.05  4.07  2.31

# %%
di.T #Транспонирование данных
# Out:
#          0        1     2        3     4          5          6          7      \
# carat     0.23     0.21  0.23     0.29  0.31       0.24       0.24       0.26
# cut      Ideal  Premium  Good  Premium  Good  Very Good  Very Good  Very Good
# color        E        E     E        I     J          J          I          H
# clarity    SI2      SI1   VS1      VS2   SI2       VVS2       VVS1        SI1
# depth     61.5     59.8  56.9     62.4  63.3       62.8       62.3       61.9
# table     55.0     61.0  65.0     58.0  58.0       57.0       57.0       55.0
# price      326      326   327      334   335        336        336        337
# x         3.95     3.89  4.05      4.2  4.34       3.94       3.95       4.07
# y         3.98     3.84  4.07     4.23  4.35       3.96       3.98       4.11
# z         2.43     2.31  2.31     2.63  2.75       2.48       2.47       2.53
#
#         8          9      ...    53930    53931      53932      53933  \
# ...

# %%
di.shape
# Out:
# (53940, 10)

# %%
di.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
di[['carat', 'price']].max()
# Out:
# carat        5.01
# price    18823.00
# dtype: float64

# %%
di.loc[di['carat'] > 4, ['carat','price']]
# Out:
#        carat  price
# 25998   4.01  15223
# 25999   4.01  15223
# 27130   4.13  17329
# 27415   5.01  18018
# 27630   4.50  18531

# %%
list(set(di['clarity']))
# Out:
# ['VS1', 'SI1', 'VVS1', 'IF', 'I1', 'VS2', 'VVS2', 'SI2']

# %%
list(set(di['cut']))
# Out:
# ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
list(set(di['color']))
# Out:
# ['I', 'D', 'F', 'G', 'E', 'H', 'J']

# %%
li_tab = list(set(di['table']))
print(li_tab)
# Out:
# [61.5, 53.1, 58.3, 43.0, 44.0, 59.3, 49.0, 50.1, 51.0, 52.0, 53.6, 53.9, 55.6, 55.2, 53.7, 53.4, 54.4, 60.4, 54.8, 54.2, 54.9, 55.8, 56.7, 57.1, 58.1, 59.8, 60.7, 64.0, 65.0, 67.0, 69.0, 66.0, 70.0, 68.0, 71.0, 73.0, 79.0, 76.0, 95.0, 61.3, 61.8, 57.6, 55.4, 59.1, 59.6, 57.9, 57.4, 61.1, 61.6, 58.4, 58.9, 62.1, 54.7, 50.0, 51.6, 52.8, 52.4, 53.0, 53.3, 53.5, 53.8, 53.2, 54.1, 54.5, 54.6, 54.3, 54.0, 55.1, 55.9, 55.7, 55.3, 55.0, 56.9, 56.5, 56.2, 56.6, 56.1, 57.8, 56.3, 57.2, 57.5, 56.4, 58.8, 58.6, 57.0, 58.0, 57.7, 59.4, 59.5, 59.0, 58.5, 59.9, 60.9, 60.1, 60.5, 60.0, 60.3, 61.0, 60.6, 60.2, 60.8, 61.4, 62.0, 62.4, 62.6, 62.2, 62.3, 63.0, 62.5, 63.5, 62.8, 63.3, 63.4, 64.3, 64.2, 65.4, 58.2, 58.7, 55.5, 59.7, 59.2, 56.0, 61.9, 61.2, 61.7, 56.8, 57.3]

# %%
di.tail(10)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53930   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53932   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
# 53933   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 53934   0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
di['carat']
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %%
di['Quality–color'] = di.cut + ', ' + di.color
di.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   Quality–color
# 0      Ideal, E
# 1    Premium, E
# 2       Good, E
# 3    Premium, I
# 4       Good, J

# %%
di.dtypes
# Out:
# carat            float64
# cut               object
# color             object
# clarity           object
# depth            float64
# table            float64
# price              int64
# x                float64
# y                float64
# z                float64
# Quality–color     object
# dtype: object

# %%
di.describe(include=['object'])
# Out:
#           cut  color clarity Quality–color
# count   53940  53940   53940         53940
# unique      5      7       8            35
# top     Ideal      G     SI1      Ideal, G
# freq    21551  11292   13065          4884

# %%
di.describe(include=['float64'])
# Out:
#               carat         depth         table             x             y  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184      5.731157      5.734526
# std        0.474011      1.432621      2.234491      1.121761      1.142135
# min        0.200000     43.000000     43.000000      0.000000      0.000000
# 25%        0.400000     61.000000     56.000000      4.710000      4.720000
# 50%        0.700000     61.800000     57.000000      5.700000      5.710000
# 75%        1.040000     62.500000     59.000000      6.540000      6.540000
# max        5.010000     79.000000     95.000000     10.740000     58.900000
#
#                   z
# count  53940.000000
# mean       3.538734
# std        0.705699
# min        0.000000
# 25%        2.910000
# 50%        3.530000
# 75%        4.040000
# max       31.800000

# %%
di.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
print("Rrenaming two of the columns of the said dataframe:")
di.rename(columns={'color':'diamond_color', 'clarity':'dimaond_clarity'}, inplace=True)
di.head(3)
# Out:
# Rrenaming two of the columns of the said dataframe:
#    carat      cut diamond_color dimaond_clarity  depth  table  price     x  \
# 0   0.23    Ideal             E             SI2   61.5   55.0    326  3.95
# 1   0.21  Premium             E             SI1   59.8   61.0    326  3.89
# 2   0.23     Good             E             VS1   56.9   65.0    327  4.05
#
#       y     z Quality–color
# 0  3.98  2.43      Ideal, E
# 1  3.84  2.31    Premium, E
# 2  4.07  2.31       Good, E

# %%
di_cols = ['new_carat', 'new_cut', 'new_color', 'new_clarity', 'new_depth', 'new_table', 'new_price', 'new_x', 'new_y', 'new_z', 'new_Quality–color']
di.columns = di_cols
di.head(3)
# Out:
#    new_carat  new_cut new_color new_clarity  new_depth  new_table  new_price  \
# 0       0.23    Ideal         E         SI2       61.5       55.0        326
# 1       0.21  Premium         E         SI1       59.8       61.0        326
# 2       0.23     Good         E         VS1       56.9       65.0        327
#
#    new_x  new_y  new_z new_Quality–color
# 0   3.95   3.98   2.43          Ideal, E
# 1   3.89   3.84   2.31        Premium, E
# 2   4.05   4.07   2.31           Good, E

# %%
di = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv', sep = ',')
di.drop('cut', axis=1, inplace=True)
di.head(2)
# Out:
#    carat color clarity  depth  table  price     x     y     z
# 0   0.23     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21     E     SI1   59.8   61.0    326  3.89  3.84  2.31

# %%
di = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv', sep = ',')
di.drop(['color', 'y'], axis=1, inplace=True)
di.head(3)
# Out:
#    carat      cut clarity  depth  table  price     x     z
# 0   0.23    Ideal     SI2   61.5   55.0    326  3.95  2.43
# 1   0.21  Premium     SI1   59.8   61.0    326  3.89  2.31
# 2   0.23     Good     VS1   56.9   65.0    327  4.05  2.31

# %%
#Удаление снескольких строк (ось = 0 относится к строкам)
di = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv', sep = ',')
di.drop([2, 4, 5], axis=0, inplace=True)
di.head(7)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %% [markdown]
# Анализ файла grozny.csv. Перед загрузкой его надо в Notepade+ преобразованть в UTF-8
#
# ![Grozny.jpg](data:image/jpeg;base64,...)

# %%
gr = pd.read_csv('/content/sample_data/Grozny.csv', sep = ';')

# %%
gr
# Out:
#          id                Region     City  \
# 0    188961  Чеченская республика  Грозный
# 1    161189  Чеченская республика  Грозный
# 2    150962  Чеченская Республика  Грозный
# 3    152198  Чеченская Республика  Грозный
# 4    159357  Чеченская Республика  Грозный
# ..      ...                   ...      ...
# 405  163050  Чеченская республика  Грозный
# 406  240583  Чеченская республика  Грозный
# 407  150969  Чеченская Республика  Грозный
# 408  150985  Чеченская Республика  Грозный
# 409  151024  Чеченская Республика  Грозный
#
#                                                Address  MinPricePerSqMeter  \
# 0    Чеченская Республика, Грозный, Алтайская улица...               34000
# 1    Чеченская Республика, Грозный, Алтайская улица...               27000
# 2    Чеченская Республика, Грозный, Алтайская улица...               29000
# 3    Чеченская Республика, Грозный, Артельная улица, 1               35000
# ...

# %%
gr.shape
# Out:
# (410, 14)

# %% [markdown]
# ## Kahoot
#
# https://kahoot.it/
#
# Преподаватель отправит вам ссылку на игру в чат
